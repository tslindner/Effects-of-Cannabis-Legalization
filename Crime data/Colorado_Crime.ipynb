# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2010 data
col_10_path = "County_data/Colorado_county_2010.csv"
col_10 = pd.read_csv(col_10_path)
col_10 = col_10[['County','Violent crime']]
col_10.head()
# Out:
#                County  Violent crime
# 0        Adams County          477.0
# 1     Arapahoe County          204.0
# 2      Boulder County           56.0
# 3  Clear Creek County           21.0
# 4      Douglas County          269.0

# %%
# 2011 data
col_11_path = "County_data/Colorado_county_2011.csv"
col_11 = pd.read_csv(col_11_path)
col_11 = col_11[['County','Violent crime']]
col_11.head()
# Out:
#                County  Violent crime
# 0        Adams County          385.0
# 1     Arapahoe County          236.0
# 2      Boulder County           65.0
# 3  Clear Creek County           17.0
# 4      Douglas County          312.0

# %%
# 2012 data
file_path = "County_data/Colorado_county_2012.csv"
col_12 = pd.read_csv(file_path)
col_12 = col_12[['County','Violent crime']]
col_12.head()
# Out:
#                County  Violent crime
# 0        Adams County          419.0
# 1     Arapahoe County          218.0
# 2      Boulder County           54.0
# 3  Clear Creek County           14.0
# 4      Douglas County          139.0

# %%
# 2013 data
file_path = "County_data/Colorado_county_2013.csv"
col_13 = pd.read_csv(file_path)
col_13 = col_13[['County','Violent crime']]
col_13.head()
# Out:
#                County  Violent crime
# 0        Adams County          429.0
# 1     Arapahoe County          225.0
# 2  Clear Creek County           17.0
# 3      Douglas County          126.0
# 4      El Paso County          475.0

# %%
# 2014 data
file_path = "County_data/Colorado_county_2014.csv"
col_14 = pd.read_csv(file_path)
col_14 = col_14[['County','Violent crime']]
col_14.head()
# Out:
#                County  Violent crime
# 0        Adams County          462.0
# 1     Arapahoe County          215.0
# 2  Clear Creek County           28.0
# 3      Douglas County          151.0
# 4       Elbert County            0.0

# %%
# 2015 data
file_path = "County_data/Colorado_county_2015.csv"
col_15 = pd.read_csv(file_path)
col_15 = col_15[['County','Violent crime']]
col_15.head()
# Out:
#                County  Violent crime
# 0        Adams County          476.0
# 1     Arapahoe County          225.0
# 2      Boulder County          106.0
# 3  Clear Creek County           19.0
# 4      Douglas County          164.0

# %%
# 2016 data
file_path = "County_data/Colorado_county_2016.csv"
col_16 = pd.read_csv(file_path)
col_16 = col_16[['County','Violent crime']]
col_16.head()
# Out:
#                County  Violent crime
# 0        Adams County          523.0
# 1     Arapahoe County          269.0
# 2      Boulder County           83.0
# 3  Clear Creek County           15.0
# 4      Douglas County          326.0

# %%
# Merge 2010-2011 data
result_1 = pd.merge(col_10, col_11, how='left', on=['County'])
result_1 = result_1.rename(columns={'Violent crime_x':'2010','Violent crime_y':'2011'})
result_1.head()
# Out:
#                County   2010   2011
# 0        Adams County  477.0  385.0
# 1     Arapahoe County  204.0  236.0
# 2      Boulder County   56.0   65.0
# 3  Clear Creek County   21.0   17.0
# 4      Douglas County  269.0  312.0

# %%
# Merge with 2012 data
result_2 = pd.merge(result_1, col_12, how='left', on=['County'])
result_2.head()
# Out:
#                County   2010   2011  Violent crime
# 0        Adams County  477.0  385.0          419.0
# 1     Arapahoe County  204.0  236.0          218.0
# 2      Boulder County   56.0   65.0           54.0
# 3  Clear Creek County   21.0   17.0           14.0
# 4      Douglas County  269.0  312.0          139.0

# %%
# Merge with 2013 data
result_3 = pd.merge(result_2, col_13, how='left', on=['County'])
result_3 = result_3.rename(columns={'Violent crime_x':'2012','Violent crime_y':'2013'})
result_3.head()
# Out:
#                County   2010   2011   2012   2013
# 0        Adams County  477.0  385.0  419.0  429.0
# 1     Arapahoe County  204.0  236.0  218.0  225.0
# 2      Boulder County   56.0   65.0   54.0    NaN
# 3  Clear Creek County   21.0   17.0   14.0   17.0
# 4      Douglas County  269.0  312.0  139.0  126.0

# %%
# Merge with 2014 data
result_4 = pd.merge(result_3, col_14, how='left', on=['County'])
result_4 = result_4.dropna()
result_4.head()
# Out:
#                County   2010   2011   2012   2013  Violent crime
# 0        Adams County  477.0  385.0  419.0  429.0          462.0
# 1     Arapahoe County  204.0  236.0  218.0  225.0          215.0
# 3  Clear Creek County   21.0   17.0   14.0   17.0           28.0
# 4      Douglas County  269.0  312.0  139.0  126.0          151.0
# 5       Gilpin County   12.0    2.0   14.0    4.0           10.0

# %%
# Merge with 2015 data
result_5 = pd.merge(result_4, col_15, how='left', on=['County'])
result_5.head()
# Out:
#                County   2010   2011   2012   2013  Violent crime_x  \
# 0        Adams County  477.0  385.0  419.0  429.0            462.0
# 1     Arapahoe County  204.0  236.0  218.0  225.0            215.0
# 2  Clear Creek County   21.0   17.0   14.0   17.0             28.0
# 3      Douglas County  269.0  312.0  139.0  126.0            151.0
# 4       Gilpin County   12.0    2.0   14.0    4.0             10.0
#
#    Violent crime_y
# 0            476.0
# 1            225.0
# 2             19.0
# 3            164.0
# 4              3.0

# %%
# Merge with 2016 data, drop NA results, and rename columns
result_6 = pd.merge(result_5, col_16, how='left', on=['County'])
result_6 = result_6.dropna()
result_6 = result_6.rename(columns={'Violent crime_x':'2014','Violent crime_y':'2015','Violent crime':'2016'})
result_6.head()
# Out:
#                County   2010   2011   2012   2013   2014   2015   2016
# 0        Adams County  477.0  385.0  419.0  429.0  462.0  476.0  523.0
# 1     Arapahoe County  204.0  236.0  218.0  225.0  215.0  225.0  269.0
# 2  Clear Creek County   21.0   17.0   14.0   17.0   28.0   19.0   15.0
# 3      Douglas County  269.0  312.0  139.0  126.0  151.0  164.0  326.0
# 4       Gilpin County   12.0    2.0   14.0    4.0   10.0    3.0    4.0

# %%
# Sum of all the totals
sum_2010 = result_6['2010'].sum()
sum_2011 = result_6['2011'].sum()
sum_2012 = result_6['2012'].sum()
sum_2013 = result_6['2013'].sum()
sum_2014 = result_6['2014'].sum()
sum_2015 = result_6['2015'].sum()
sum_2016 = result_6['2016'].sum()
sum_all = [sum_2010, sum_2011, sum_2012, sum_2013, sum_2014, sum_2015, sum_2016]

# %%
# Plotting the data
x_vals = ['2010','2011','2012','2013','2014','2015','2016']

plt.plot(x_vals, sum_all, color = 'forestgreen', linewidth = 4)
plt.title("Crime per Year in Colorado (2010-2016)", loc = 'center',fontsize = 17,fontweight = 3, color = 'black' )
plt.xlabel("Year" , fontsize = 15, fontweight = 3, color = 'black' )
plt.ylabel("Sum of Crime", fontsize = 15, fontweight= 3, color = 'black' )
sns.set(rc={'axes.facecolor':'whitesmoke', 'figure.facecolor':'lightgrey'})
plt.grid(color='gainsboro')
plt.xlim(2010,2016)
plt.savefig("Colorado_Crime_2010_2016")
