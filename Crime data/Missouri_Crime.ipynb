# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2010 data
mo_10_path = "County_data/Missouri_county_2010.csv"
mo_10 = pd.read_csv(mo_10_path)
mo_11 = mo_10[['County','Violent crime']]
mo_10.head()
# Out:
#       County  Violent crime
# 0     Andrew            3.0
# 1      Bates           18.0
# 2  Bollinger            3.0
# 3      Boone          116.0
# 4   Buchanan           24.0

# %%
# 2011 data
mo_11_path = "County_data/Missouri_county_2011.csv"
mo_11 = pd.read_csv(mo_11_path)
mo_11 = mo_11[['County','Violent crime']]
mo_11.head()
# Out:
#       County  Violent crime
# 0     Andrew              2
# 1      Bates             31
# 2  Bollinger             14
# 3      Boone             90
# 4   Buchanan             22

# %%
# 2012 data
file_path = "County_data/Missouri_county_2012.csv"
mo_12 = pd.read_csv(file_path)
mo_12 = mo_12[['County','Violent crime']]
mo_12.head()
# Out:
#       County  Violent crime
# 0     Andrew              5
# 1      Bates             33
# 2  Bollinger             12
# 3      Boone            114
# 4   Buchanan             20

# %%
# 2013 data
file_path = "County_data/Missouri_county_2013.csv"
mo_13 = pd.read_csv(file_path)
mo_13 = mo_13[['County','Violent crime']]
mo_13.head()
# Out:
#       County  Violent crime
# 0     Andrew             14
# 1      Bates             74
# 2  Bollinger             33
# 3      Boone            111
# 4   Buchanan             21

# %%
# 2014 data
file_path = "County_data/Missouri_county_2014.csv"
mo_14 = pd.read_csv(file_path)
mo_14 = mo_14[['County','Violent crime']]
mo_14.head()
# Out:
#       County  Violent crime
# 0     Andrew             18
# 1      Bates             63
# 2  Bollinger             12
# 3      Boone            131
# 4   Buchanan             19

# %%
# 2015 data
file_path = "County_data/Missouri_county_2015.csv"
mo_15 = pd.read_csv(file_path)
mo_15 = mo_15[['County','Violent crime']]
mo_15.head()
# Out:
#       County  Violent crime
# 0     Andrew             13
# 1      Bates             50
# 2  Bollinger             46
# 3      Boone            126
# 4   Buchanan             28

# %%
# 2016 data
file_path = "County_data/Missouri_county_2016.csv"
mo_16 = pd.read_csv(file_path)
mo_16 = mo_16[['County','Violent crime']]
mo_16.head()
# Out:
#       County  Violent crime
# 0     Andrew           33.0
# 1      Bates           50.0
# 2  Bollinger           87.0
# 3      Boone          125.0
# 4   Buchanan           28.0

# %%
# Merge 2010-2011 data
result_1 = pd.merge(mo_10, mo_11, how='left', on=['County'])
result_1 = result_1.rename(columns={'Violent crime_x':'2010','Violent crime_y':'2011'})
result_1.head()
# Out:
#       County   2010  2011
# 0     Andrew    3.0   2.0
# 1      Bates   18.0  31.0
# 2  Bollinger    3.0  14.0
# 3      Boone  116.0  90.0
# 4   Buchanan   24.0  22.0

# %%
# Merge with 2012 data
result_2 = pd.merge(result_1, mo_12, how='left', on=['County'])
result_2.head()
# Out:
#       County   2010  2011  Violent crime
# 0     Andrew    3.0   2.0            5.0
# 1      Bates   18.0  31.0           33.0
# 2  Bollinger    3.0  14.0           12.0
# 3      Boone  116.0  90.0          114.0
# 4   Buchanan   24.0  22.0           20.0

# %%
# Merge 2013 data
result_3 = pd.merge(result_2, mo_13, how='left', on=['County'])
result_3 = result_3.rename(columns={'Violent crime_x':'2012','Violent crime_y':'2013'})
result_3.head()
# Out:
#       County   2010  2011   2012   2013
# 0     Andrew    3.0   2.0    5.0   14.0
# 1      Bates   18.0  31.0   33.0   74.0
# 2  Bollinger    3.0  14.0   12.0   33.0
# 3      Boone  116.0  90.0  114.0  111.0
# 4   Buchanan   24.0  22.0   20.0   21.0

# %%
# Merge with 2014 data
result_4 = pd.merge(result_3, mo_14, how='left', on=['County'])
result_4 = result_4.dropna()
result_4.head()
# Out:
#       County   2010  2011   2012   2013  Violent crime
# 0     Andrew    3.0   2.0    5.0   14.0           18.0
# 1      Bates   18.0  31.0   33.0   74.0           63.0
# 2  Bollinger    3.0  14.0   12.0   33.0           12.0
# 3      Boone  116.0  90.0  114.0  111.0          131.0
# 4   Buchanan   24.0  22.0   20.0   21.0           19.0

# %%
# Merge with 2015 data
result_5 = pd.merge(result_4, mo_15, how='left', on=['County'])
result_5.head()
# Out:
#       County   2010  2011   2012   2013  Violent crime_x  Violent crime_y
# 0     Andrew    3.0   2.0    5.0   14.0             18.0             13.0
# 1      Bates   18.0  31.0   33.0   74.0             63.0             50.0
# 2  Bollinger    3.0  14.0   12.0   33.0             12.0             46.0
# 3      Boone  116.0  90.0  114.0  111.0            131.0            126.0
# 4   Buchanan   24.0  22.0   20.0   21.0             19.0             28.0

# %%
# Merge with 2016 data
result_6 = pd.merge(result_5, mo_16, how='left', on=['County'])
result_6 = result_6.dropna()
result_6 = result_6.rename(columns={'Violent crime_x':'2014','Violent crime_y':'2015','Violent crime':'2016'})
result_6.head()
# Out:
#       County   2010  2011   2012   2013   2014   2015   2016
# 0     Andrew    3.0   2.0    5.0   14.0   18.0   13.0   33.0
# 1      Bates   18.0  31.0   33.0   74.0   63.0   50.0   50.0
# 2  Bollinger    3.0  14.0   12.0   33.0   12.0   46.0   87.0
# 3      Boone  116.0  90.0  114.0  111.0  131.0  126.0  125.0
# 4   Buchanan   24.0  22.0   20.0   21.0   19.0   28.0   28.0

# %%
# Sum of all results
sum_2010 = result_6['2010'].sum()
sum_2011 = result_6['2011'].sum()
sum_2012 = result_6['2012'].sum()
sum_2013 = result_6['2013'].sum()
sum_2014 = result_6['2014'].sum()
sum_2015 = result_6['2015'].sum()
sum_2016 = result_6['2016'].sum()
sum_all = [sum_2010, sum_2011, sum_2012, sum_2013, sum_2014, sum_2015, sum_2016]

# %%
# Plotting the data
x_vals = ['2010','2011','2012','2013','2014','2015','2016']

plt.plot(x_vals, sum_all, color = 'forestgreen', linewidth = 4)
plt.title("Crime per Year in Missouri (2010-2016)", loc = 'center',fontsize = 17,fontweight = 3, color = 'black' )
plt.xlabel("Year" , fontsize = 15, fontweight = 3, color = 'black' )
plt.ylabel("Sum of Crime", fontsize = 15, fontweight= 3, color = 'black' )
sns.set(rc={'axes.facecolor':'whitesmoke', 'figure.facecolor':'lightgrey'})
plt.grid(color='gainsboro')
plt.xlim(2010,2016)
plt.savefig("Missouri_Crime_2010_2016")
