# %%
# Dependencies
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
# Crime 2010 
ca_2010 = "County_data/California_county_2010.csv"
ca_10 = pd.read_csv(ca_2010)
ca_10 = ca_10[['County','Violent crime']]
ca_10.head()
# Out:
#          County  Violent crime
# 0       Alameda          698.0
# 1         Butte          133.0
# 2  Contra Costa          449.0
# 3     El Dorado          256.0
# 4        Fresno          727.0

# %%
# Crime 2011
ca_2011 = "County_data/California_county_2011.csv"
ca_11 = pd.read_csv(ca_2011)
ca_11 = ca_11[['County','Violent crime']]
ca_11.head()
# Out:
#          County  Violent crime
# 0       Alameda          725.0
# 1         Butte          106.0
# 2  Contra Costa          456.0
# 3     El Dorado          192.0
# 4        Fresno          740.0

# %%
# Crime 2012
ca_2012 = "County_data/California_county_2012.csv"
ca_12 = pd.read_csv(ca_2012)
ca_12 = ca_12[['County','Violent crime']]
ca_12.head()
# Out:
#          County  Violent crime
# 0       Alameda          651.0
# 1         Butte          126.0
# 2  Contra Costa          472.0
# 3     El Dorado          241.0
# 4        Fresno          825.0

# %%
# Crime 2013
ca_2013 = "County_data/California_county_2013.csv"
ca_13 = pd.read_csv(ca_2013)
ca_13 = ca_13[['County','Violent crime']]
ca_13.head()
# Out:
#          County  Violent crime
# 0       Alameda          648.0
# 1         Butte           96.0
# 2  Contra Costa          429.0
# 3     El Dorado          210.0
# 4        Fresno          849.0

# %%
# Crime 2014
ca_2014 = "County_data/California_county_2014.csv"
ca_14 = pd.read_csv(ca_2014)
ca_14 = ca_14[['County','Violent crime']]
ca_14.head()
# Out:
#          County  Violent crime
# 0      Alameda3          588.0
# 1         Butte           82.0
# 2  Contra Costa          412.0
# 3     El Dorado          240.0
# 4        Fresno          735.0

# %%
# Crime 2015
ca_2015 = "County_data/California_county_2015.csv"
ca_15 = pd.read_csv(ca_2015)
ca_15 = ca_15[['County','Violent crime']]
ca_15.head()
# Out:
#          County  Violent crime
# 0      Alameda3          588.0
# 1         Butte           82.0
# 2  Contra Costa          412.0
# 3     El Dorado          240.0
# 4        Fresno          735.0

# %%
# Crime 2016
ca_2016 = "County_data/California_county_2016.csv"
ca_16 = pd.read_csv(ca_2016)
ca_16 = ca_16[['County','Violent crime']]
ca_16.head()
# Out:
#          County  Violent crime
# 0       Alameda          589.0
# 1         Butte          183.0
# 2  Contra Costa          347.0
# 3     El Dorado          291.0
# 4        Fresno         1177.0

# %%
# Merging 2010-2011 and renaming columns
ca10_11 = pd.merge(ca_10, ca_11, how='left', on=['County'])
ca10_11 = ca10_11.rename(columns={'Violent crime_x':'2010','Violent crime_y':'2011'})
ca10_11.head()
# Out:
#          County   2010   2011
# 0       Alameda  698.0  725.0
# 1         Butte  133.0  106.0
# 2  Contra Costa  449.0  456.0
# 3     El Dorado  256.0  192.0
# 4        Fresno  727.0  740.0

# %%
# Merging 2011-2012
merge_12 = pd.merge(ca10_11, ca_12, how='left', on=['County'])
merge_12.head()
# Out:
#          County   2010   2011  Violent crime
# 0       Alameda  698.0  725.0          651.0
# 1         Butte  133.0  106.0          126.0
# 2  Contra Costa  449.0  456.0          472.0
# 3     El Dorado  256.0  192.0          241.0
# 4        Fresno  727.0  740.0          825.0

# %%
# Merging 2012-2013 and renaming the columns
merge_13 = pd.merge(merge_12, ca_13, how='left', on=['County'])
merge_13 = merge_13.rename(columns={'Violent crime_x':'2012','Violent crime_y':'2013'})
merge_13.head()
# Out:
#          County   2010   2011   2012   2013
# 0       Alameda  698.0  725.0  651.0  648.0
# 1         Butte  133.0  106.0  126.0   96.0
# 2  Contra Costa  449.0  456.0  472.0  429.0
# 3     El Dorado  256.0  192.0  241.0  210.0
# 4        Fresno  727.0  740.0  825.0  849.0

# %%
# Merging 2013-2014
merge_14 = pd.merge(merge_13, ca_14, how='left', on=['County'])
merge_14.head()
# Out:
#          County   2010   2011   2012   2013  Violent crime
# 0       Alameda  698.0  725.0  651.0  648.0            NaN
# 1         Butte  133.0  106.0  126.0   96.0           82.0
# 2  Contra Costa  449.0  456.0  472.0  429.0          412.0
# 3     El Dorado  256.0  192.0  241.0  210.0          240.0
# 4        Fresno  727.0  740.0  825.0  849.0          735.0

# %%
# Merging 2014-2015 and renaming the columns
merge_15 = pd.merge(merge_14, ca_15, how='left', on=['County'])
merge_15 = merge_15.rename(columns={'Violent crime_x':'2014','Violent crime_y':'2015'})
merge_15.head()
# Out:
#          County   2010   2011   2012   2013   2014   2015
# 0       Alameda  698.0  725.0  651.0  648.0    NaN    NaN
# 1         Butte  133.0  106.0  126.0   96.0   82.0   82.0
# 2  Contra Costa  449.0  456.0  472.0  429.0  412.0  412.0
# 3     El Dorado  256.0  192.0  241.0  210.0  240.0  240.0
# 4        Fresno  727.0  740.0  825.0  849.0  735.0  735.0

# %%
# Merging 2015-2016 and renaming the columns
merge_16 = pd.merge(merge_15, ca_16, how='left', on=['County'])
merge_16 = merge_16.rename(columns={'Violent crime':'2016'})
merge_16.head()
# Out:
#          County   2010   2011   2012   2013   2014   2015    2016
# 0       Alameda  698.0  725.0  651.0  648.0    NaN    NaN   589.0
# 1         Butte  133.0  106.0  126.0   96.0   82.0   82.0   183.0
# 2  Contra Costa  449.0  456.0  472.0  429.0  412.0  412.0   347.0
# 3     El Dorado  256.0  192.0  241.0  210.0  240.0  240.0   291.0
# 4        Fresno  727.0  740.0  825.0  849.0  735.0  735.0  1177.0

# %%
# Drop NA Values
result = merge_16.dropna()
result.head()
# Out:
#          County   2010   2011   2012   2013   2014   2015    2016
# 1         Butte  133.0  106.0  126.0   96.0   82.0   82.0   183.0
# 2  Contra Costa  449.0  456.0  472.0  429.0  412.0  412.0   347.0
# 3     El Dorado  256.0  192.0  241.0  210.0  240.0  240.0   291.0
# 4        Fresno  727.0  740.0  825.0  849.0  735.0  735.0  1177.0
# 5      Imperial  265.0  110.0  139.0  199.0  214.0  214.0   161.0

# %%
# Summing all the values for charting
sum_2010 = result['2010'].sum()
sum_2011 = result['2011'].sum()
sum_2012 = result['2012'].sum()
sum_2013 = result['2013'].sum()
sum_2014 = result['2014'].sum()
sum_2015 = result['2015'].sum()
sum_2016 = result['2016'].sum()
sum_all = [sum_2010, sum_2011, sum_2012, sum_2013, sum_2014, sum_2015, sum_2016]

# %%
# Plotting the data
x_vals = ['2010','2011','2012','2013','2014','2015','2016']

plt.plot(x_vals, sum_all, color = 'forestgreen', linewidth = 4)
plt.title("Crime per Year in California (2010-2016)", loc = 'center',fontsize = 17,fontweight = 3, color = 'black' )
plt.xlabel("Year" , fontsize = 15, fontweight = 3, color = 'black' )
plt.ylabel("Sum of Crime", fontsize = 15, fontweight= 3, color = 'black' )
sns.set(rc={'axes.facecolor':'whitesmoke', 'figure.facecolor':'lightgrey'})
plt.grid(color='gainsboro')
plt.xlim(2010,2016)
plt.savefig("California_Crime_2010_2016")
