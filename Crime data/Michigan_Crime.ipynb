# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
col_10_path = "County_data/Michigan_county_2010.csv"
col_10 = pd.read_csv(col_10_path)
col_10 = col_10[['County','Violent crime']]
col_10.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-5a1a364c00de> in <module>()
#       1 col_10_path = "County_data/Michigan_county_2010.csv"
#       2 col_10 = pd.read_csv(col_10_path)
# ----> 3 col_10 = col_10[['County','Violent crime']]
#       4 col_10.head()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['Violent crime'] not in index"

# %%
col_11_path = "County_data/Colorado_county_2011.csv"
col_11 = pd.read_csv(col_11_path)
col_11 = col_11[['County','Violent crime']]
col_11.head()
# Out:
#                County  Violent crime
# 0        Adams County          385.0
# 1     Arapahoe County          236.0
# 2      Boulder County           65.0
# 3  Clear Creek County           17.0
# 4      Douglas County          312.0

# %%
file_path = "County_data/Colorado_county_2012.csv"
col_12 = pd.read_csv(file_path)
col_12 = col_12[['County','Violent crime']]
col_12.head()
# Out:
#                County  Violent crime
# 0        Adams County          419.0
# 1     Arapahoe County          218.0
# 2      Boulder County           54.0
# 3  Clear Creek County           14.0
# 4      Douglas County          139.0

# %%
file_path = "County_data/Colorado_county_2013.csv"
col_13 = pd.read_csv(file_path)
col_13 = col_13[['County','Violent crime']]
col_13.head()
# Out:
#                County  Violent crime
# 0        Adams County          429.0
# 1     Arapahoe County          225.0
# 2  Clear Creek County           17.0
# 3      Douglas County          126.0
# 4      El Paso County          475.0

# %%
file_path = "County_data/Colorado_county_2014.csv"
col_14 = pd.read_csv(file_path)
col_14 = col_14[['County','Violent crime']]
col_14.head()
# Out:
#                County  Violent crime
# 0        Adams County          462.0
# 1     Arapahoe County          215.0
# 2  Clear Creek County           28.0
# 3      Douglas County          151.0
# 4       Elbert County            0.0

# %%
file_path = "County_data/Colorado_county_2015.csv"
col_15 = pd.read_csv(file_path)
col_15 = col_15[['County','Violent crime']]
col_15.head()
# Out:
#                County  Violent crime
# 0        Adams County          476.0
# 1     Arapahoe County          225.0
# 2      Boulder County          106.0
# 3  Clear Creek County           19.0
# 4      Douglas County          164.0

# %%
file_path = "County_data/Colorado_county_2016.csv"
col_16 = pd.read_csv(file_path)
col_16 = col_16[['County','Violent crime']]
col_16.head()
# Out:
#                County  Violent crime
# 0        Adams County          523.0
# 1     Arapahoe County          269.0
# 2      Boulder County           83.0
# 3  Clear Creek County           15.0
# 4      Douglas County          326.0

# %%
result_1 = pd.merge(col_10, col_11, how='left', on=['County'])
result_1 = result_1.rename(columns={'Violent crime_x':'2010','Violent crime_y':'2011'})
result_1
# Out:
#                 County   2010   2011
# 0         Adams County  477.0  385.0
# 1      Arapahoe County  204.0  236.0
# 2       Boulder County   56.0   65.0
# 3   Clear Creek County   21.0   17.0
# 4       Douglas County  269.0  312.0
# 5        Gilpin County   12.0    2.0
# 6     Jefferson County  183.0  127.0
# 7       Larimer County  134.0  107.0
# 8          Mesa County  163.0  181.0
# 9          Park County   20.0    7.0
# 10       Pueblo County   31.0   28.0
# 11       Teller County    9.0   23.0
# 12         Weld County  120.0  185.0
# 13      Alamosa County    1.0    1.0
# 14         Baca County    0.0    NaN
# 15         Bent County    2.0    2.0
# 16      Chaffee County   11.0    8.0
# 17     Cheyenne County    0.0    0.0
# 18      Crowley County    4.0    4.0
# 19        Delta County   19.0   19.0
# 20      Dolores County    0.0    3.0
# 21        Eagle County   44.0   25.0
# 22      Fremont County    NaN   36.0
# 23        Grand County   12.0   10.0
# 24     Gunnison County   10.0    8.0
# 25   Kit Carson County    2.0    2.0
# 26         Lake County    2.0    NaN
# 27   Las Animas County    0.0    0.0
# 28      Lincoln County    2.0    4.0
# 29        Logan County   10.0   10.0
# ..                 ...    ...    ...
# 55                 NaN    NaN    NaN
# 56                 NaN    NaN    NaN
# 57                 NaN    NaN    NaN
# 58                 NaN    NaN    NaN
# 59                 NaN    NaN    NaN
# 60                 NaN    NaN    NaN
# 61                 NaN    NaN    NaN
# 62                 NaN    NaN    NaN
# 63                 NaN    NaN    NaN
# 64                 NaN    NaN    NaN
# 65                 NaN    NaN    NaN
# 66                 NaN    NaN    NaN
# 67                 NaN    NaN    NaN
# 68                 NaN    NaN    NaN
# 69                 NaN    NaN    NaN
# 70                 NaN    NaN    NaN
# 71                 NaN    NaN    NaN
# 72                 NaN    NaN    NaN
# 73                 NaN    NaN    NaN
# 74                 NaN    NaN    NaN
# 75                 NaN    NaN    NaN
# 76                 NaN    NaN    NaN
# 77                 NaN    NaN    NaN
# 78                 NaN    NaN    NaN
# 79                 NaN    NaN    NaN
# 80                 NaN    NaN    NaN
# 81                 NaN    NaN    NaN
# 82                 NaN    NaN    NaN
# 83                 NaN    NaN    NaN
# 84                 NaN    NaN    NaN
#
# [85 rows x 3 columns]

# %%
result_2 = pd.merge(result_1, col_12, how='left', on=['County'])
result_2
# Out:
#                    County   2010   2011  Violent crime
# 0            Adams County  477.0  385.0          419.0
# 1         Arapahoe County  204.0  236.0          218.0
# 2          Boulder County   56.0   65.0           54.0
# 3      Clear Creek County   21.0   17.0           14.0
# 4          Douglas County  269.0  312.0          139.0
# 5           Gilpin County   12.0    2.0           14.0
# 6        Jefferson County  183.0  127.0          148.0
# 7          Larimer County  134.0  107.0          150.0
# 8             Mesa County  163.0  181.0          194.0
# 9             Park County   20.0    7.0           20.0
# 10          Pueblo County   31.0   28.0            NaN
# 11          Teller County    9.0   23.0           21.0
# 12            Weld County  120.0  185.0          151.0
# 13         Alamosa County    1.0    1.0            7.0
# 14            Baca County    0.0    NaN            3.0
# 15            Bent County    2.0    2.0           14.0
# 16         Chaffee County   11.0    8.0            3.0
# 17        Cheyenne County    0.0    0.0            2.0
# 18         Crowley County    4.0    4.0           11.0
# 19           Delta County   19.0   19.0            9.0
# 20         Dolores County    0.0    3.0            1.0
# 21           Eagle County   44.0   25.0           26.0
# 22         Fremont County    NaN   36.0           34.0
# 23           Grand County   12.0   10.0            NaN
# 24        Gunnison County   10.0    8.0           11.0
# 25      Kit Carson County    2.0    2.0            2.0
# 26            Lake County    2.0    NaN            5.0
# 27      Las Animas County    0.0    0.0            NaN
# 28         Lincoln County    2.0    4.0            1.0
# 29           Logan County   10.0   10.0           15.0
# ...                   ...    ...    ...            ...
# 60199                 NaN    NaN    NaN            NaN
# 60200                 NaN    NaN    NaN            NaN
# 60201                 NaN    NaN    NaN            NaN
# 60202                 NaN    NaN    NaN            NaN
# 60203                 NaN    NaN    NaN            NaN
# 60204                 NaN    NaN    NaN            NaN
# 60205                 NaN    NaN    NaN            NaN
# 60206                 NaN    NaN    NaN            NaN
# 60207                 NaN    NaN    NaN            NaN
# 60208                 NaN    NaN    NaN            NaN
# 60209                 NaN    NaN    NaN            NaN
# 60210                 NaN    NaN    NaN            NaN
# 60211                 NaN    NaN    NaN            NaN
# 60212                 NaN    NaN    NaN            NaN
# 60213                 NaN    NaN    NaN            NaN
# 60214                 NaN    NaN    NaN            NaN
# 60215                 NaN    NaN    NaN            NaN
# 60216                 NaN    NaN    NaN            NaN
# 60217                 NaN    NaN    NaN            NaN
# 60218                 NaN    NaN    NaN            NaN
# 60219                 NaN    NaN    NaN            NaN
# 60220                 NaN    NaN    NaN            NaN
# 60221                 NaN    NaN    NaN            NaN
# 60222                 NaN    NaN    NaN            NaN
# 60223                 NaN    NaN    NaN            NaN
# 60224                 NaN    NaN    NaN            NaN
# 60225                 NaN    NaN    NaN            NaN
# 60226                 NaN    NaN    NaN            NaN
# 60227                 NaN    NaN    NaN            NaN
# 60228                 NaN    NaN    NaN            NaN
#
# [60229 rows x 4 columns]

# %%
result_3 = pd.merge(result_2, col_13, how='left', on=['County'])
result_3 = result_3.rename(columns={'Violent crime_x':'2012','Violent crime_y':'2013'})
result_3
# Out:
#                     County   2010   2011   2012   2013
# 0             Adams County  477.0  385.0  419.0  429.0
# 1          Arapahoe County  204.0  236.0  218.0  225.0
# 2           Boulder County   56.0   65.0   54.0    NaN
# 3       Clear Creek County   21.0   17.0   14.0   17.0
# 4           Douglas County  269.0  312.0  139.0  126.0
# 5            Gilpin County   12.0    2.0   14.0    4.0
# 6         Jefferson County  183.0  127.0  148.0  142.0
# 7           Larimer County  134.0  107.0  150.0  121.0
# 8              Mesa County  163.0  181.0  194.0  180.0
# 9              Park County   20.0    7.0   20.0   13.0
# 10           Pueblo County   31.0   28.0    NaN   50.0
# 11           Teller County    9.0   23.0   21.0   10.0
# 12             Weld County  120.0  185.0  151.0  121.0
# 13          Alamosa County    1.0    1.0    7.0    1.0
# 14             Baca County    0.0    NaN    3.0    8.0
# 15             Bent County    2.0    2.0   14.0   10.0
# 16          Chaffee County   11.0    8.0    3.0    9.0
# 17         Cheyenne County    0.0    0.0    2.0    1.0
# 18          Crowley County    4.0    4.0   11.0    5.0
# 19            Delta County   19.0   19.0    9.0    5.0
# 20          Dolores County    0.0    3.0    1.0    1.0
# 21            Eagle County   44.0   25.0   26.0   34.0
# 22          Fremont County    NaN   36.0   34.0   30.0
# 23            Grand County   12.0   10.0    NaN    NaN
# 24         Gunnison County   10.0    8.0   11.0    2.0
# 25       Kit Carson County    2.0    2.0    2.0   10.0
# 26             Lake County    2.0    NaN    5.0   12.0
# 27       Las Animas County    0.0    0.0    NaN    6.0
# 28          Lincoln County    2.0    4.0    1.0    1.0
# 29            Logan County   10.0   10.0   15.0    8.0
# ...                    ...    ...    ...    ...    ...
# 421315                 NaN    NaN    NaN    NaN    NaN
# 421316                 NaN    NaN    NaN    NaN    NaN
# 421317                 NaN    NaN    NaN    NaN    NaN
# 421318                 NaN    NaN    NaN    NaN    NaN
# 421319                 NaN    NaN    NaN    NaN    NaN
# 421320                 NaN    NaN    NaN    NaN    NaN
# 421321                 NaN    NaN    NaN    NaN    NaN
# 421322                 NaN    NaN    NaN    NaN    NaN
# 421323                 NaN    NaN    NaN    NaN    NaN
# 421324                 NaN    NaN    NaN    NaN    NaN
# 421325                 NaN    NaN    NaN    NaN    NaN
# 421326                 NaN    NaN    NaN    NaN    NaN
# 421327                 NaN    NaN    NaN    NaN    NaN
# 421328                 NaN    NaN    NaN    NaN    NaN
# 421329                 NaN    NaN    NaN    NaN    NaN
# 421330                 NaN    NaN    NaN    NaN    NaN
# 421331                 NaN    NaN    NaN    NaN    NaN
# 421332                 NaN    NaN    NaN    NaN    NaN
# 421333                 NaN    NaN    NaN    NaN    NaN
# 421334                 NaN    NaN    NaN    NaN    NaN
# 421335                 NaN    NaN    NaN    NaN    NaN
# 421336                 NaN    NaN    NaN    NaN    NaN
# 421337                 NaN    NaN    NaN    NaN    NaN
# 421338                 NaN    NaN    NaN    NaN    NaN
# 421339                 NaN    NaN    NaN    NaN    NaN
# 421340                 NaN    NaN    NaN    NaN    NaN
# 421341                 NaN    NaN    NaN    NaN    NaN
# 421342                 NaN    NaN    NaN    NaN    NaN
# 421343                 NaN    NaN    NaN    NaN    NaN
# 421344                 NaN    NaN    NaN    NaN    NaN
#
# [421345 rows x 5 columns]

# %%
result_4 = pd.merge(result_3, col_14, how='left', on=['County'])
result_4 = result_4.dropna()
result_4
# Out:
#                 County   2010   2011   2012   2013  Violent crime
# 0         Adams County  477.0  385.0  419.0  429.0          462.0
# 1      Arapahoe County  204.0  236.0  218.0  225.0          215.0
# 3   Clear Creek County   21.0   17.0   14.0   17.0           28.0
# 4       Douglas County  269.0  312.0  139.0  126.0          151.0
# 5        Gilpin County   12.0    2.0   14.0    4.0           10.0
# 6     Jefferson County  183.0  127.0  148.0  142.0          167.0
# 7       Larimer County  134.0  107.0  150.0  121.0          109.0
# 8          Mesa County  163.0  181.0  194.0  180.0          203.0
# 9          Park County   20.0    7.0   20.0   13.0           18.0
# 11       Teller County    9.0   23.0   21.0   10.0           34.0
# 12         Weld County  120.0  185.0  151.0  121.0          154.0
# 13      Alamosa County    1.0    1.0    7.0    1.0            0.0
# 15         Bent County    2.0    2.0   14.0   10.0            8.0
# 16      Chaffee County   11.0    8.0    3.0    9.0            4.0
# 17     Cheyenne County    0.0    0.0    2.0    1.0            2.0
# 18      Crowley County    4.0    4.0   11.0    5.0            3.0
# 19        Delta County   19.0   19.0    9.0    5.0            4.0
# 20      Dolores County    0.0    3.0    1.0    1.0            2.0
# 21        Eagle County   44.0   25.0   26.0   34.0           45.0
# 24     Gunnison County   10.0    8.0   11.0    2.0            1.0
# 25   Kit Carson County    2.0    2.0    2.0   10.0            4.0
# 28      Lincoln County    2.0    4.0    1.0    1.0            4.0
# 29        Logan County   10.0   10.0   15.0    8.0           11.0
# 30       Moffat County    4.0    4.0    3.0    0.0            0.0
# 31    Montezuma County   42.0   31.0   32.0   28.0           34.0
# 32     Montrose County   21.0   36.0   30.0   25.0           33.0
# 33       Morgan County    2.0    2.0    8.0   17.0           11.0
# 35       Pitkin County    7.0   14.0   11.0    0.0            4.0
# 36      Prowers County    5.0    8.0   10.0    3.0            2.0
# 38        Routt County   11.0   12.0    6.0    5.0            6.0
# 40   San Miguel County    3.0    0.0    0.0    0.0            0.0

# %%
result_5 = pd.merge(result_4, col_15, how='left', on=['County'])
result_5
# Out:
#                 County   2010   2011   2012   2013  Violent crime_x  \
# 0         Adams County  477.0  385.0  419.0  429.0            462.0
# 1      Arapahoe County  204.0  236.0  218.0  225.0            215.0
# 2   Clear Creek County   21.0   17.0   14.0   17.0             28.0
# 3       Douglas County  269.0  312.0  139.0  126.0            151.0
# 4        Gilpin County   12.0    2.0   14.0    4.0             10.0
# 5     Jefferson County  183.0  127.0  148.0  142.0            167.0
# 6       Larimer County  134.0  107.0  150.0  121.0            109.0
# 7          Mesa County  163.0  181.0  194.0  180.0            203.0
# 8          Park County   20.0    7.0   20.0   13.0             18.0
# 9        Teller County    9.0   23.0   21.0   10.0             34.0
# 10         Weld County  120.0  185.0  151.0  121.0            154.0
# 11      Alamosa County    1.0    1.0    7.0    1.0              0.0
# 12         Bent County    2.0    2.0   14.0   10.0              8.0
# 13      Chaffee County   11.0    8.0    3.0    9.0              4.0
# 14     Cheyenne County    0.0    0.0    2.0    1.0              2.0
# 15      Crowley County    4.0    4.0   11.0    5.0              3.0
# 16        Delta County   19.0   19.0    9.0    5.0              4.0
# 17      Dolores County    0.0    3.0    1.0    1.0              2.0
# 18        Eagle County   44.0   25.0   26.0   34.0             45.0
# 19     Gunnison County   10.0    8.0   11.0    2.0              1.0
# 20   Kit Carson County    2.0    2.0    2.0   10.0              4.0
# 21      Lincoln County    2.0    4.0    1.0    1.0              4.0
# 22        Logan County   10.0   10.0   15.0    8.0             11.0
# 23       Moffat County    4.0    4.0    3.0    0.0              0.0
# 24    Montezuma County   42.0   31.0   32.0   28.0             34.0
# 25     Montrose County   21.0   36.0   30.0   25.0             33.0
# 26       Morgan County    2.0    2.0    8.0   17.0             11.0
# 27       Pitkin County    7.0   14.0   11.0    0.0              4.0
# 28      Prowers County    5.0    8.0   10.0    3.0              2.0
# 29        Routt County   11.0   12.0    6.0    5.0              6.0
# 30   San Miguel County    3.0    0.0    0.0    0.0              0.0
#
#     Violent crime_y
# 0             476.0
# 1             225.0
# 2              19.0
# 3             164.0
# 4               3.0
# 5             181.0
# 6             168.0
# 7             201.0
# 8              13.0
# 9              18.0
# 10            141.0
# 11              NaN
# 12              NaN
# 13              9.0
# 14              6.0
# 15              5.0
# 16             13.0
# 17              3.0
# 18             39.0
# 19              2.0
# 20              7.0
# 21              0.0
# 22             13.0
# 23              0.0
# 24             20.0
# 25             11.0
# 26             18.0
# 27              3.0
# 28              9.0
# 29             12.0
# 30              NaN

# %%
result_6 = pd.merge(result_5, col_16, how='left', on=['County'])
result_6 = result_6.dropna()
result_6 = result_6.rename(columns={'Violent crime_x':'2014','Violent crime_y':'2015','Violent crime':'2016'})
result_6
# Out:
#                 County   2010   2011   2012   2013   2014   2015   2016
# 0         Adams County  477.0  385.0  419.0  429.0  462.0  476.0  523.0
# 1      Arapahoe County  204.0  236.0  218.0  225.0  215.0  225.0  269.0
# 2   Clear Creek County   21.0   17.0   14.0   17.0   28.0   19.0   15.0
# 3       Douglas County  269.0  312.0  139.0  126.0  151.0  164.0  326.0
# 4        Gilpin County   12.0    2.0   14.0    4.0   10.0    3.0    4.0
# 5     Jefferson County  183.0  127.0  148.0  142.0  167.0  181.0  224.0
# 6       Larimer County  134.0  107.0  150.0  121.0  109.0  168.0  171.0
# 7          Mesa County  163.0  181.0  194.0  180.0  203.0  201.0  180.0
# 8          Park County   20.0    7.0   20.0   13.0   18.0   13.0   16.0
# 9        Teller County    9.0   23.0   21.0   10.0   34.0   18.0    6.0
# 10         Weld County  120.0  185.0  151.0  121.0  154.0  141.0  102.0
# 13      Chaffee County   11.0    8.0    3.0    9.0    4.0    9.0    0.0
# 14     Cheyenne County    0.0    0.0    2.0    1.0    2.0    6.0    1.0
# 15      Crowley County    4.0    4.0   11.0    5.0    3.0    5.0    5.0
# 16        Delta County   19.0   19.0    9.0    5.0    4.0   13.0   16.0
# 17      Dolores County    0.0    3.0    1.0    1.0    2.0    3.0    5.0
# 18        Eagle County   44.0   25.0   26.0   34.0   45.0   39.0   33.0
# 19     Gunnison County   10.0    8.0   11.0    2.0    1.0    2.0    3.0
# 20   Kit Carson County    2.0    2.0    2.0   10.0    4.0    7.0    5.0
# 21      Lincoln County    2.0    4.0    1.0    1.0    4.0    0.0    1.0
# 22        Logan County   10.0   10.0   15.0    8.0   11.0   13.0   15.0
# 23       Moffat County    4.0    4.0    3.0    0.0    0.0    0.0    3.0
# 24    Montezuma County   42.0   31.0   32.0   28.0   34.0   20.0   21.0
# 25     Montrose County   21.0   36.0   30.0   25.0   33.0   11.0   12.0
# 26       Morgan County    2.0    2.0    8.0   17.0   11.0   18.0   10.0
# 27       Pitkin County    7.0   14.0   11.0    0.0    4.0    3.0    5.0
# 28      Prowers County    5.0    8.0   10.0    3.0    2.0    9.0    3.0
# 29        Routt County   11.0   12.0    6.0    5.0    6.0   12.0    7.0

# %%
sum_2010 = result_6['2010'].sum()
sum_2011 = result_6['2011'].sum()
sum_2012 = result_6['2012'].sum()
sum_2013 = result_6['2013'].sum()
sum_2014 = result_6['2014'].sum()
sum_2015 = result_6['2015'].sum()
sum_2016 = result_6['2016'].sum()
sum_all = [sum_2010, sum_2011, sum_2012, sum_2013, sum_2014, sum_2015, sum_2016]

# %%
#x values for the chart
x_vals = ['2010','2011','2012','2013','2014','2015','2016']

plt.plot(x_vals, sum_all)
sns.set_style("darkgrid")
plt.savefig("Colorado_Crime_2010_2016")
