# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2010 Data
mi_10_path = "County_data/Michigan_county_2010.csv"
mi_10 = pd.read_csv(mi_10_path)
mi_10 = mi_10[['County','Violent crime']]
mi_10.head()
# Out:
#     County  Violent crime
# 0    Barry             37
# 1      Bay             40
# 2  Berrien            108
# 3  Calhoun             65
# 4     Cass             39

# %%
# 2011 Data
mi_11_path = "County_data/Michigan_county_2011.csv"
mi_11 = pd.read_csv(mi_11_path)
mi_11 = mi_11[['County','Violent crime']]
mi_11.head()
# Out:
#     County  Violent crime
# 0    Barry             40
# 1      Bay             46
# 2  Berrien            116
# 3  Calhoun             73
# 4     Cass             27

# %%
# 2012 Data
file_path = "County_data/Michigan_county_2012.csv"
mi_12 = pd.read_csv(file_path)
mi_12 = mi_12[['County','Violent crime']]
mi_12.head()
# Out:
#     County  Violent crime
# 0      Bay           44.0
# 1  Berrien           91.0
# 2  Clinton           10.0
# 3   Ingham           93.0
# 4  Jackson          103.0

# %%
# 2013 Data
file_path = "County_data/Michigan_county_2013.csv"
mi_13 = pd.read_csv(file_path)
mi_13 = mi_13[['County','Violent crime']]
mi_13.head()
# Out:
#     County  Violent crime
# 0    Barry           34.0
# 1      Bay           37.0
# 2  Calhoun           76.0
# 3     Cass           44.0
# 4  Clinton           21.0

# %%
# 2014 data
file_path = "County_data/Michigan_county_2014.csv"
mi_14 = pd.read_csv(file_path)
mi_14 = mi_14[['County','Violent crime']]
mi_14.head()
# Out:
#     County  Violent crime
# 0    Barry           24.0
# 1      Bay           55.0
# 2  Berrien           83.0
# 3     Cass           52.0
# 4  Clinton           22.0

# %%
# 2015 Data
file_path = "County_data/Michigan_county_2015.csv"
mi_15 = pd.read_csv(file_path)
mi_15 = mi_15[['County','Violent crime']]
mi_15.head()
# Out:
#     County  Violent crime
# 0    Barry           44.0
# 1      Bay           46.0
# 2  Berrien          100.0
# 3  Calhoun          110.0
# 4     Cass           53.0

# %%
# 2016 data
file_path = "County_data/Michigan_county_2016.csv"
mi_16 = pd.read_csv(file_path)
mi_16 = mi_16[['County','Violent crime']]
mi_16.head()
# Out:
#     County  Violent crime
# 0    Barry           34.0
# 1      Bay           44.0
# 2  Berrien          122.0
# 3  Calhoun          121.0
# 4     Cass           50.0

# %%
# Merge 2010-2011 data
result_1 = pd.merge(mi_10, mi_11, how='left', on=['County'])
result_1 = result_1.rename(columns={'Violent crime_x':'2010','Violent crime_y':'2011'})
result_1.head()
# Out:
#     County  2010   2011
# 0    Barry    37   40.0
# 1      Bay    40   46.0
# 2  Berrien   108  116.0
# 3  Calhoun    65   73.0
# 4     Cass    39   27.0

# %%
# Merging with 2012 data
result_2 = pd.merge(result_1, mi_12, how='left', on=['County'])
result_2.head()
# Out:
#     County  2010   2011  Violent crime
# 0    Barry    37   40.0            NaN
# 1      Bay    40   46.0           44.0
# 2  Berrien   108  116.0           91.0
# 3  Calhoun    65   73.0            NaN
# 4     Cass    39   27.0            NaN

# %%
# Merging with 2013 data
result_3 = pd.merge(result_2, mi_13, how='left', on=['County'])
result_3 = result_3.rename(columns={'Violent crime_x':'2012','Violent crime_y':'2013'})
result_3.head()
# Out:
#     County  2010   2011  2012  2013
# 0    Barry    37   40.0   NaN  34.0
# 1      Bay    40   46.0  44.0  37.0
# 2  Berrien   108  116.0  91.0   NaN
# 3  Calhoun    65   73.0   NaN  76.0
# 4     Cass    39   27.0   NaN  44.0

# %%
# Merging with 2014 data
result_4 = pd.merge(result_3, mi_14, how='left', on=['County'])
result_4 = result_4.dropna()
result_4.head()
# Out:
#      County  2010   2011   2012   2013  Violent crime
# 1       Bay    40   46.0   44.0   37.0           55.0
# 5   Clinton     7   17.0   10.0   21.0           22.0
# 8    Ingham    97   94.0   93.0  118.0          115.0
# 9     Ionia    43   31.0   29.0   33.0           43.0
# 10  Jackson   122  134.0  103.0  129.0          171.0

# %%
# Merging with 2015 data
result_5 = pd.merge(result_4, mi_15, how='left', on=['County'])
result_5.head()
# Out:
#     County  2010   2011   2012   2013  Violent crime_x  Violent crime_y
# 0      Bay    40   46.0   44.0   37.0             55.0             46.0
# 1  Clinton     7   17.0   10.0   21.0             22.0             17.0
# 2   Ingham    97   94.0   93.0  118.0            115.0            134.0
# 3    Ionia    43   31.0   29.0   33.0             43.0             34.0
# 4  Jackson   122  134.0  103.0  129.0            171.0            163.0

# %%
# Merging with 2016 data
result_6 = pd.merge(result_5, mi_16, how='left', on=['County'])
result_6 = result_6.dropna()
result_6 = result_6.rename(columns={'Violent crime_x':'2014','Violent crime_y':'2015','Violent crime':'2016'})
result_6.head()
# Out:
#     County  2010   2011   2012   2013   2014   2015   2016
# 0      Bay    40   46.0   44.0   37.0   55.0   46.0   44.0
# 1  Clinton     7   17.0   10.0   21.0   22.0   17.0   23.0
# 2   Ingham    97   94.0   93.0  118.0  115.0  134.0  146.0
# 3    Ionia    43   31.0   29.0   33.0   43.0   34.0   45.0
# 4  Jackson   122  134.0  103.0  129.0  171.0  163.0  218.0

# %%
# Sum of all values
sum_2010 = result_6['2010'].sum()
sum_2011 = result_6['2011'].sum()
sum_2012 = result_6['2012'].sum()
sum_2013 = result_6['2013'].sum()
sum_2014 = result_6['2014'].sum()
sum_2015 = result_6['2015'].sum()
sum_2016 = result_6['2016'].sum()
sum_all = [sum_2010, sum_2011, sum_2012, sum_2013, sum_2014, sum_2015, sum_2016]

# %%
# Plotting the data
x_vals = ['2010','2011','2012','2013','2014','2015','2016']

plt.plot(x_vals, sum_all, color = 'forestgreen', linewidth = 4)
plt.title("Crime per Year in Michigan(2010-2016)", loc = 'center',fontsize = 17,fontweight = 3, color = 'black' )
plt.xlabel("Year" , fontsize = 15, fontweight = 3, color = 'black' )
plt.ylabel("Sum of Crime", fontsize = 15, fontweight= 3, color = 'black' )
sns.set(rc={'axes.facecolor':'whitesmoke', 'figure.facecolor':'lightgrey'})
plt.grid(color='gainsboro')
plt.xlim(2010,2016)
plt.savefig("Michigan_Crime_2010_2016")
