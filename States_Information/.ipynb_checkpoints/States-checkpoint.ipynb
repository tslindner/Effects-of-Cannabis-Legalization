# %%
import pandas as pd
import csv

# %%
df = pd.read_csv("states.csv", encoding='latin-1')

# %%
df
# Out:
#                    State Abbreviation
# 0                Alabama           AL
# 1                 Alaska           AK
# 2                Arizona           AZ
# 3               Arkansas           AR
# 4             California           CA
# 5               Colorado           CO
# 6            Connecticut           CT
# 7               Delaware           DE
# 8   District of Columbia           DC
# 9                Florida           FL
# 10               Georgia           GA
# 11                Hawaii           HI
# 12                 Idaho           ID
# 13              Illinois           IL
# 14               Indiana           IN
# 15                  Iowa           IA
# 16                Kansas           KS
# 17              Kentucky           KY
# 18             Louisiana           LA
# 19                 Maine           ME
# 20               Montana           MT
# 21              Nebraska           NE
# 22                Nevada           NV
# 23         New Hampshire           NH
# ...

# %%
df["Legal"] = ""
df["Possession"] = ""
df["Retail"] = ""

# %%
df.at[1, 'Legal'] = 2014
df.at[4, 'Legal'] = 2016
df.at[5, 'Legal'] = 2012
df.at[19, 'Legal'] = 2016
df.at[33, 'Legal'] = 2016
df.at[22, 'Legal'] = 2016
df.at[31, 'Legal'] = 2014
df.at[47, 'Legal'] = 2012
df.at[8, 'Legal'] = 2014

# %%
df.at[1, 'Possession'] = 2015
df.at[4, 'Possession'] = 2016
df.at[5, 'Possession'] = 2012
df.at[19, 'Possession'] = 2017
df.at[33, 'Possession'] = 2016
df.at[22, 'Possession'] = 2017
df.at[31, 'Possession'] = 2015
df.at[47, 'Possession'] = 2012
df.at[8, 'Possession'] = 2015

# %%
df
# Out:
#                    State Abbreviation Legal Possession Retail
# 0                Alabama           AL
# 1                 Alaska           AK  2014       2015
# 2                Arizona           AZ
# 3               Arkansas           AR
# 4             California           CA  2016       2016
# 5               Colorado           CO  2012       2012
# 6            Connecticut           CT
# 7               Delaware           DE
# 8   District of Columbia           DC  2014       2015
# 9                Florida           FL
# 10               Georgia           GA
# 11                Hawaii           HI
# 12                 Idaho           ID
# 13              Illinois           IL
# 14               Indiana           IN
# 15                  Iowa           IA
# 16                Kansas           KS
# 17              Kentucky           KY
# 18             Louisiana           LA
# 19                 Maine           ME  2016       2017
# 20               Montana           MT
# ...

# %%
df.at[1, 'Retail'] = 2016
df.at[4, 'Retail'] = 2018
df.at[5, 'Retail'] = 2014
df.at[19, 'Retail'] = 'expected 2018'
df.at[33, 'Retail'] = 'expected 2018'
df.at[22, 'Retail'] = 2017
df.at[31, 'Retail'] = 2016
df.at[47, 'Retail'] = 2014
df
# Out:
#                    State Abbreviation Legal Possession         Retail
# 0                Alabama           AL
# 1                 Alaska           AK  2014       2015           2016
# 2                Arizona           AZ
# 3               Arkansas           AR
# 4             California           CA  2016       2016           2018
# 5               Colorado           CO  2012       2012           2014
# 6            Connecticut           CT
# 7               Delaware           DE
# 8   District of Columbia           DC  2014       2015
# 9                Florida           FL
# 10               Georgia           GA
# 11                Hawaii           HI
# 12                 Idaho           ID
# 13              Illinois           IL
# 14               Indiana           IN
# 15                  Iowa           IA
# 16                Kansas           KS
# 17              Kentucky           KY
# 18             Louisiana           LA
# ...

# %%
df.columns = ['State', 'Abbr', 'R-Legal', 'R-Posess', 'R-Retail']

# %%
df
# Out:
#                    State Abbr R-Legal R-Posess       R-Retail
# 0                Alabama   AL
# 1                 Alaska   AK    2014     2015           2016
# 2                Arizona   AZ
# 3               Arkansas   AR
# 4             California   CA    2016     2016           2018
# 5               Colorado   CO    2012     2012           2014
# 6            Connecticut   CT
# 7               Delaware   DE
# 8   District of Columbia   DC    2014     2015
# 9                Florida   FL
# 10               Georgia   GA
# 11                Hawaii   HI
# 12                 Idaho   ID
# 13              Illinois   IL
# 14               Indiana   IN
# 15                  Iowa   IA
# 16                Kansas   KS
# 17              Kentucky   KY
# 18             Louisiana   LA
# 19                 Maine   ME    2016     2017  expected 2018
# 20               Montana   MT
# 21              Nebraska   NE
# 22                Nevada   NV    2016     2017           2017
# ...

# %%
df.at[45, 'R-Legal'] = 2018
df.at[45, 'R-Posess'] = 'expected 2018'
df
# Out:
#                    State Abbr R-Legal       R-Posess       R-Retail
# 0                Alabama   AL
# 1                 Alaska   AK    2014           2015           2016
# 2                Arizona   AZ
# 3               Arkansas   AR
# 4             California   CA    2016           2016           2018
# 5               Colorado   CO    2012           2012           2014
# 6            Connecticut   CT
# 7               Delaware   DE
# 8   District of Columbia   DC    2014           2015
# 9                Florida   FL
# 10               Georgia   GA
# 11                Hawaii   HI
# 12                 Idaho   ID
# 13              Illinois   IL
# 14               Indiana   IN
# 15                  Iowa   IA
# 16                Kansas   KS
# 17              Kentucky   KY
# 18             Louisiana   LA
# 19                 Maine   ME    2016           2017  expected 2018
# 20               Montana   MT
# 21              Nebraska   NE
# ...

# %%
df.at[24, 'R-Legal'] = 'expected 2018'
df.at[34, 'R-Legal'] = 'expected 2018'
df.at[30, 'R-Legal'] = 'expected 2018'
df.at[44, 'R-Legal'] = 'expected 2018'
df.at[37, 'R-Legal'] = 'expected 2018'
df.at[46, 'R-Legal'] = 'expected 2018'

# %%
df
# Out:
#                    State Abbr        R-Legal       R-Posess       R-Retail
# 0                Alabama   AL
# 1                 Alaska   AK           2014           2015           2016
# 2                Arizona   AZ
# 3               Arkansas   AR
# 4             California   CA           2016           2016           2018
# 5               Colorado   CO           2012           2012           2014
# 6            Connecticut   CT
# 7               Delaware   DE
# 8   District of Columbia   DC           2014           2015
# 9                Florida   FL
# 10               Georgia   GA
# 11                Hawaii   HI
# 12                 Idaho   ID
# 13              Illinois   IL
# 14               Indiana   IN
# 15                  Iowa   IA
# 16                Kansas   KS
# 17              Kentucky   KY
# 18             Louisiana   LA
# 19                 Maine   ME           2016           2017  expected 2018
# 20               Montana   MT
# 21              Nebraska   NE
# ...

# %%
df2 = df

# %%
df2
# Out:
#                    State Abbr        R-Legal       R-Posess       R-Retail
# 0                Alabama   AL
# 1                 Alaska   AK           2014           2015           2016
# 2                Arizona   AZ
# 3               Arkansas   AR
# 4             California   CA           2016           2016           2018
# 5               Colorado   CO           2012           2012           2014
# 6            Connecticut   CT
# 7               Delaware   DE
# 8   District of Columbia   DC           2014           2015
# 9                Florida   FL
# 10               Georgia   GA
# 11                Hawaii   HI
# 12                 Idaho   ID
# 13              Illinois   IL
# 14               Indiana   IN
# 15                  Iowa   IA
# 16                Kansas   KS
# 17              Kentucky   KY
# 18             Louisiana   LA
# 19                 Maine   ME           2016           2017  expected 2018
# 20               Montana   MT
# 21              Nebraska   NE
# ...

# %%
df2['Decrim-Pos'] = ""

# %%
df.at[1, 'Decrim-Pos'] = True
df.at[4, 'Decrim-Pos'] = True
df.at[5, 'Decrim-Pos'] = True
df.at[6, 'Decrim-Pos'] = True
df.at[7, 'Decrim-Pos'] = True
df.at[8, 'Decrim-Pos'] = True
df.at[13, 'Decrim-Pos'] = True
df.at[19, 'Decrim-Pos'] = True
df.at[32, 'Decrim-Pos'] = True
df.at[33, 'Decrim-Pos'] = True
df.at[35, 'Decrim-Pos'] = True
df.at[36, 'Decrim-Pos'] = True
df.at[37, 'Decrim-Pos'] = True
df.at[21, 'Decrim-Pos'] = True
df.at[22, 'Decrim-Pos'] = True
df.at[23, 'Decrim-Pos'] = True
df.at[26, 'Decrim-Pos'] = True
df.at[27, 'Decrim-Pos'] = True
df.at[29, 'Decrim-Pos'] = True
df.at[31, 'Decrim-Pos'] = True
df.at[39, 'Decrim-Pos'] = True
df.at[45, 'Decrim-Pos'] = True

# %%
df
# Out:
#                    State Abbr        R-Legal       R-Posess       R-Retail  \
# 0                Alabama   AL
# 1                 Alaska   AK           2014           2015           2016
# 2                Arizona   AZ
# 3               Arkansas   AR
# 4             California   CA           2016           2016           2018
# 5               Colorado   CO           2012           2012           2014
# 6            Connecticut   CT
# 7               Delaware   DE
# 8   District of Columbia   DC           2014           2015
# 9                Florida   FL
# 10               Georgia   GA
# 11                Hawaii   HI
# 12                 Idaho   ID
# 13              Illinois   IL
# 14               Indiana   IN
# 15                  Iowa   IA
# 16                Kansas   KS
# 17              Kentucky   KY
# 18             Louisiana   LA
# 19                 Maine   ME           2016           2017  expected 2018
# 20               Montana   MT
# 21              Nebraska   NE
# ...

# %%
df2 = df

# %%
df2
# Out:
#                    State Abbr        R-Legal       R-Posess       R-Retail  \
# 0                Alabama   AL
# 1                 Alaska   AK           2014           2015           2016
# 2                Arizona   AZ
# 3               Arkansas   AR
# 4             California   CA           2016           2016           2018
# 5               Colorado   CO           2012           2012           2014
# 6            Connecticut   CT
# 7               Delaware   DE
# 8   District of Columbia   DC           2014           2015
# 9                Florida   FL
# 10               Georgia   GA
# 11                Hawaii   HI
# 12                 Idaho   ID
# 13              Illinois   IL
# 14               Indiana   IN
# 15                  Iowa   IA
# 16                Kansas   KS
# 17              Kentucky   KY
# 18             Louisiana   LA
# 19                 Maine   ME           2016           2017  expected 2018
# 20               Montana   MT
# 21              Nebraska   NE
# ...

# %%
df2 = df2.drop([0, 2, 3, 9, 10, 11, 12, 14, 15, 16, 17, 18, 20, 25, 28, 38, 40, 41, 42, 43, 48, 49, 50])

# %%
df2
# Out:
#                    State Abbr        R-Legal       R-Posess       R-Retail  \
# 1                 Alaska   AK           2014           2015           2016
# 4             California   CA           2016           2016           2018
# 5               Colorado   CO           2012           2012           2014
# 6            Connecticut   CT
# 7               Delaware   DE
# 8   District of Columbia   DC           2014           2015
# 13              Illinois   IL
# 19                 Maine   ME           2016           2017  expected 2018
# 21              Nebraska   NE
# 22                Nevada   NV           2016           2017           2017
# 23         New Hampshire   NH
# 24            New Jersey   NJ  expected 2018
# 26              New York   NY
# 27        North Carolina   NC
# 29                  Ohio   OH
# 30              Oklahoma   OK  expected 2018
# 31                Oregon   OR           2014           2015           2016
# 32              Maryland   MD
# ...

# %%
df2.to_csv("states_output.csv", index = False )
